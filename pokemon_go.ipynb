# %%
import pandas as pd
import numpy as np

df=pd.read_csv('pokemon.csv')
df.head()
# Out:
#    pokemon_id pokemon_name  base_attack  base_defense  base_stamina  \
# 0           1    Bulbasaur          118           111           128
# 1           2      Ivysaur          151           143           155
# 2           3     Venusaur          198           189           190
# 3           4   Charmander          116            93           118
# 4           5   Charmeleon          158           126           151
#
#                   type    rarity  \
# 0  ['Grass', 'Poison']  Standard
# 1  ['Grass', 'Poison']  Standard
# 2  ['Grass', 'Poison']  Standard
# 3             ['Fire']  Standard
# 4             ['Fire']  Standard
#
#                                      charged_moves  \
# 0       ['Sludge Bomb', 'Seed Bomb', 'Power Whip']
# 1      ['Sludge Bomb', 'Solar Beam', 'Power Whip']
# 2  ['Sludge Bomb', 'Petal Blizzard', 'Solar Beam']
# 3  ['Flame Charge', 'Flame Burst', 'Flamethrower']
# 4    ['Fire Punch', 'Flame Burst', 'Flamethrower']
#
# ...

# %%
df.isnull().sum()
# Out:
# pokemon_id                        0
# pokemon_name                      0
# base_attack                       0
# base_defense                      0
# base_stamina                      0
# type                              0
# rarity                            0
# charged_moves                     0
# fast_moves                        0
# candy_required                  536
# distance                          0
# max_cp                            0
# attack_probability              103
# base_capture_rate               103
# base_flee_rate                  103
# dodge_probability               103
# max_pokemon_action_frequency    103
# min_pokemon_action_frequency    103
# found_egg                       263
# found_evolution                 263
# found_wild                      263
# found_research                  263
# found_raid                      263
# found_photobomb                 263
# dtype: int64

# %%
df['attack_probability'].value_counts()
# Out:
# attack_probability
# 0.10    624
# 0.20    158
# 0.30     49
# 0.05     26
# 0.40     15
# 0.70      8
# 0.25      8
# 0.15      5
# 0.45      3
# 0.01      2
# 0.12      1
# 0.00      1
# 0.50      1
# 0.60      1
# 0.35      1
# 0.13      1
# Name: count, dtype: int64

# %%
df.drop(['pokemon_name','type','fast_moves','charged_moves','max_pokemon_action_frequency','found_photobomb','found_research','found_wild','found_evolution','found_egg','min_pokemon_action_frequency','max_pokemon_action_frequency','base_flee_rate','base_capture_rate','candy_required'],inplace=True,axis=1)
df
# Out:
#       pokemon_id  base_attack  base_defense  base_stamina     rarity  \
# 0              1          118           111           128   Standard
# 1              2          151           143           155   Standard
# 2              3          198           189           190   Standard
# 3              4          116            93           118   Standard
# 4              5          158           126           151   Standard
# ...          ...          ...           ...           ...        ...
# 1002        1004          269           221           146  Legendary
# 1003        1005          280           196           233   Standard
# 1004        1006          279           171           179   Standard
# 1005        1007          263           223           205  Legendary
# 1006        1008          263           223           205  Legendary
#
#       distance  max_cp  attack_probability  dodge_probability found_raid
# ...

# %%
df
# Out:
#       pokemon_id  base_attack  base_defense  base_stamina     rarity  \
# 0              1          118           111           128   Standard
# 1              2          151           143           155   Standard
# 2              3          198           189           190   Standard
# 3              4          116            93           118   Standard
# 4              5          158           126           151   Standard
# ...          ...          ...           ...           ...        ...
# 1002        1004          269           221           146  Legendary
# 1003        1005          280           196           233   Standard
# 1004        1006          279           171           179   Standard
# 1005        1007          263           223           205  Legendary
# 1006        1008          263           223           205  Legendary
#
#       distance  max_cp  attack_probability  dodge_probability found_raid
# ...

# %%
df.isnull().sum()
# Out:
# pokemon_id              0
# base_attack             0
# base_defense            0
# base_stamina            0
# rarity                  0
# distance                0
# max_cp                  0
# attack_probability    103
# dodge_probability     103
# found_raid            263
# dtype: int64

# %%
df['attack_probability'].value_counts()
# Out:
# attack_probability
# 0.10    624
# 0.20    158
# 0.30     49
# 0.05     26
# 0.40     15
# 0.70      8
# 0.25      8
# 0.15      5
# 0.45      3
# 0.01      2
# 0.12      1
# 0.00      1
# 0.50      1
# 0.60      1
# 0.35      1
# 0.13      1
# Name: count, dtype: int64

# %%
df['attack_probability'].fillna(df['attack_probability'].mode()[0], inplace=True)
df['attack_probability'].value_counts()
# Out:
# attack_probability
# 0.10    727
# 0.20    158
# 0.30     49
# 0.05     26
# 0.40     15
# 0.70      8
# 0.25      8
# 0.15      5
# 0.45      3
# 0.01      2
# 0.12      1
# 0.00      1
# 0.50      1
# 0.60      1
# 0.35      1
# 0.13      1
# Name: count, dtype: int64

# %%
df['dodge_probability'].value_counts()
# Out:
# dodge_probability
# 0.15    671
# 0.30     62
# 0.20     60
# 0.10     47
# 0.05     30
# 0.00     15
# 0.25     10
# 0.45      3
# 0.40      2
# 0.35      2
# 1.00      1
# 0.02      1
# Name: count, dtype: int64

# %%
df['dodge_probability'].fillna(df['dodge_probability'].mode()[0], inplace=True)
df['dodge_probability'].value_counts()
# Out:
# dodge_probability
# 0.15    774
# 0.30     62
# 0.20     60
# 0.10     47
# 0.05     30
# 0.00     15
# 0.25     10
# 0.45      3
# 0.40      2
# 0.35      2
# 1.00      1
# 0.02      1
# Name: count, dtype: int64

# %%
df['found_raid'].fillna(df['found_raid'].mode()[0], inplace=True)
df['found_raid'].value_counts()
# Out:
# found_raid
# True     718
# False    289
# Name: count, dtype: int64

# %%
df.isnull().sum()
# Out:
# pokemon_id            0
# base_attack           0
# base_defense          0
# base_stamina          0
# rarity                0
# distance              0
# max_cp                0
# attack_probability    0
# dodge_probability     0
# found_raid            0
# dtype: int64

# %%
df
# Out:
#       pokemon_id  base_attack  base_defense  base_stamina     rarity  \
# 0              1          118           111           128   Standard
# 1              2          151           143           155   Standard
# 2              3          198           189           190   Standard
# 3              4          116            93           118   Standard
# 4              5          158           126           151   Standard
# ...          ...          ...           ...           ...        ...
# 1002        1004          269           221           146  Legendary
# 1003        1005          280           196           233   Standard
# 1004        1006          279           171           179   Standard
# 1005        1007          263           223           205  Legendary
# 1006        1008          263           223           205  Legendary
#
#       distance  max_cp  attack_probability  dodge_probability  found_raid
# ...

# %%
df['rarity'].value_counts()
# Out:
# rarity
# Standard       910
# Legendary       64
# Mythic          22
# Ultra beast     11
# Name: count, dtype: int64

# %%
df['rarity'].replace(to_replace=['Ultra beast','Mythic','Legendary','Standard'],value=(0,1,2,3),inplace=True)

# %%
df['rarity'].value_counts()
# Out:
# rarity
# 3    910
# 2     64
# 1     22
# 0     11
# Name: count, dtype: int64

# %%
df['found_raid'].value_counts()
# Out:
# found_raid
# True     718
# False    289
# Name: count, dtype: int64

# %%
from sklearn.preprocessing import LabelEncoder

# Initialize the LabelEncoder
label_encoder = LabelEncoder()

# Apply label encoding to the 'found_raid' column
df['found_raid'] = label_encoder.fit_transform(df['found_raid'])

# Check value counts
df['found_raid'].value_counts()
# Out:
# found_raid
# 1    718
# 0    289
# Name: count, dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1007 entries, 0 to 1006
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   pokemon_id          1007 non-null   int64
#  1   base_attack         1007 non-null   int64
#  2   base_defense        1007 non-null   int64
#  3   base_stamina        1007 non-null   int64
#  4   rarity              1007 non-null   int64
#  5   distance            1007 non-null   int64
#  6   max_cp              1007 non-null   int64
#  7   attack_probability  1007 non-null   float64
#  8   dodge_probability   1007 non-null   float64
#  9   found_raid          1007 non-null   int64
# dtypes: float64(2), int64(8)
# memory usage: 78.8 KB

# %%
df.drop(['pokemon_id'],inplace=True,axis=1)

# %%
X=df.values

# %%
X
# Out:
# array([[1.18e+02, 1.11e+02, 1.28e+02, ..., 1.00e-01, 1.50e-01, 1.00e+00],
#        [1.51e+02, 1.43e+02, 1.55e+02, ..., 1.00e-01, 1.50e-01, 1.00e+00],
#        [1.98e+02, 1.89e+02, 1.90e+02, ..., 2.00e-01, 1.50e-01, 1.00e+00],
#        ...,
#        [2.79e+02, 1.71e+02, 1.79e+02, ..., 1.00e-01, 1.50e-01, 1.00e+00],
#        [2.63e+02, 2.23e+02, 2.05e+02, ..., 1.00e-01, 1.50e-01, 1.00e+00],
#        [2.63e+02, 2.23e+02, 2.05e+02, ..., 1.00e-01, 1.50e-01, 1.00e+00]])

# %%
from sklearn.cluster import KMeans
wcss=[]
for i in range(1,10):
  kmeans=KMeans(n_clusters=i, random_state=5)
  kmeans.fit(X)
  wcss.append(kmeans.inertia_)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# ...

# %%
import matplotlib.pyplot as plt
plt.plot(range(1,10),wcss)
plt.xlabel("cluster centroids")
plt.ylabel('Wcss')
plt.title('Elbow method')
plt.show()

# %%
kmeans=KMeans(n_clusters=3,random_state=5)
kmeans.fit(X)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# KMeans(n_clusters=3, random_state=23)

# %%
y_kmeans=kmeans.predict(X)
y_kmeans
centroids=kmeans.cluster_centers_
centroids
plt.scatter(X[y_kmeans==0,0], X[y_kmeans==0,1], color='g')
plt.scatter(X[y_kmeans==1,0], X[y_kmeans==1,1], color='b')
plt.scatter(X[y_kmeans==2,0], X[y_kmeans==2,1], color='r')
plt.scatter(centroids[:, 0], centroids[:,1], color='yellow', s=400)
plt.show()

# %%
from sklearn.cluster import KMeans
import numpy as np


# Perform K-means clustering
kmeans = KMeans(n_clusters=3, random_state=5)
kmeans.fit(X)

# Check the data points in cluster 0
cluster_0_points = X[kmeans.labels_ == 0]
print("Points in cluster 0:", cluster_0_points)

# Check the data points in cluster 1
cluster_1_points = X[kmeans.labels_ == 1]
print("Points in cluster 1:", cluster_1_points)

# Get the indices of points in cluster 0
cluster_0_indices = np.where(kmeans.labels_ == 0)[0]
print("Indices of points in cluster 0:", cluster_0_indices)
# Out:
# Points in cluster 0: [[1.18e+02 1.11e+02 1.28e+02 ... 1.00e-01 1.50e-01 1.00e+00]
#  [1.16e+02 9.30e+01 1.18e+02 ... 1.00e-01 1.50e-01 1.00e+00]
#  [9.40e+01 1.21e+02 1.27e+02 ... 1.00e-01 1.50e-01 1.00e+00]
#  ...
#  [1.19e+02 8.00e+01 2.39e+02 ... 1.00e-01 1.50e-01 1.00e+00]
#  [1.34e+02 8.60e+01 1.63e+02 ... 1.00e-01 1.50e-01 1.00e+00]
#  [1.40e+02 7.60e+01 1.28e+02 ... 1.00e-01 1.50e-01 1.00e+00]]
# Points in cluster 1: [[2.23e+02 1.73e+02 1.86e+02 ... 2.00e-01 1.50e-01 1.00e+00]
#  [2.32e+02 1.65e+02 2.16e+02 ... 1.00e-01 1.50e-01 1.00e+00]
#  [2.71e+02 1.67e+02 1.46e+02 ... 1.00e-01 1.50e-01 1.00e+00]
#  ...
#  [2.79e+02 1.71e+02 1.79e+02 ... 1.00e-01 1.50e-01 1.00e+00]
#  [2.63e+02 2.23e+02 2.05e+02 ... 1.00e-01 1.50e-01 1.00e+00]
#  [2.63e+02 2.23e+02 2.05e+02 ... 1.00e-01 1.50e-01 1.00e+00]]
# Indices of points in cluster 0: [  0   3   6   7   9  10  12  13  15  16  18  20  22  24  26  28  29  31
#   32  34  36  38  40  42  45  47  49  51  53  55  57  59  60  62  65  68
# ...
